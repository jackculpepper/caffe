# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import os
import re
import time
import images2gif
import math

from IPython.display import HTML
from IPython.display import Image
# %matplotlib inline

caffe_root = '../'
net_root = caffe_root + 'examples/cfw/'
data_root = caffe_root + 'data/cfw/'
subdirectory = '4layers_v5/'

DEPLOY_FILE = 'cfw_deploy_v5.prototxt'
MEAN_FILE = 'mean.binaryproto'
TEST_FILE = 'cfw_test.txt'
TRAIN_FILE = 'cfw_train_random.txt'
LABELS_FILE = 'cfw_labels.txt'

import sys
sys.path.insert(0, caffe_root + 'python')
sys.path.insert(0, net_root)

import caffe

plt.rcParams['figure.figsize'] = (10, 10)
plt.rcParams['image.interpolation'] = 'nearest'

# %% [markdown]
# ### Helper Functions

# %%
# Human Sorting
def tryint(s):
    try:
        return int(s)
    except:
        return s
     
def alphanum_key(s):
    """ Turn a string into a list of string and number chunks.
        "z23a" -> ["z", 23, "a"]
    """
    return [ tryint(c) for c in re.split('([0-9]+)', s) ]

def sort_nicely(l):
    """ Sort the given list in the way that humans expect.
    """
    l.sort(key=alphanum_key)
    
# our network takes BGR images, so we need to switch color channels
def switch_color(im):
    if im.ndim == 3:
        im = im[:, :, ::-1]
    
    return im 

def vis_square(data, padsize=1, padval=0):
    data -= data.min()
    data /= data.max()
    
    # force the number of filters to be square
    n = int(np.ceil(np.sqrt(data.shape[0])))
    padding = ((0, n ** 2 - data.shape[0]), (0, padsize), (0, padsize)) + ((0, 0),) * (data.ndim - 3)
    data = np.pad(data, padding, mode='constant', constant_values=(padval, padval))
    
    # tile the filters into an image
    data = data.reshape((n, n) + data.shape[1:]).transpose((0, 2, 1, 3) + tuple(range(4, data.ndim + 1)))
    data = data.reshape((n * data.shape[1], n * data.shape[3]) + data.shape[4:])
    return data

def vis_filters(data, padsize=1, padval=0):    
    # force the number of filters to be square
    n = int(np.ceil(np.sqrt(data.shape[0])))
    padding = ((0, n ** 2 - data.shape[0]), (0, padsize), (0, padsize)) + ((0, 0),) * (data.ndim - 3)
    data = np.pad(data, padding, mode='constant', constant_values=(padval, padval))
    
    # tile the filters into an image
    data = data.reshape((n, n) + data.shape[1:]).transpose((0, 2, 1, 3) + tuple(range(4, data.ndim + 1)))
    data = data.reshape((n * data.shape[1], n * data.shape[3]) + data.shape[4:])
    return data

def vis_filters_rect(data, n, padsize=1, padval=0):    
    # make a rectangle by dividing one dimension by the other
    m = data.shape[0] / n
    padding = ((0, n * m - data.shape[0]), (0, padsize), (0, padsize)) + ((0, 0),) * (data.ndim - 3)
    data = np.pad(data, padding, mode='constant', constant_values=(padval, padval))
    
    # tile the filters into an image
    data = data.reshape((n, m) + data.shape[1:]).transpose((0, 2, 1, 3) + tuple(range(4, data.ndim + 1)))
    data = data.reshape((n * data.shape[1], m * data.shape[3]) + data.shape[4:])
    return data


def norm_filters(data, type='global'):
    if type == 'global':
        data -= data.min()
        data /= data.max()
    elif type == 'cellwise':
        for i in range(data.shape[0]):
            #data[i, :, :, :] -= data[i].min()
            data[i, :, :, :] /= abs(data[i, :, :, :]).max()
    elif type == 'inputwise':
        for i in range(data.shape[1]):
            data[:, i, :, :] /= abs(data[:, i, :, :]).max()
    else:
        print "norm type unknown"
    return data

# %%
filenames = os.listdir(net_root + subdirectory)
filenames = filter(lambda f: not re.search(r'\d+$', f) == None, filenames)
sort_nicely(filenames)

print net_root + DEPLOY_FILE
print net_root + subdirectory + filenames[1]

net = caffe.Classifier(net_root + DEPLOY_FILE, net_root + subdirectory + filenames[-1])

filters = net.params['conv1'][0].data
data = filters.transpose(0, 2, 3, 1)
data = norm_filters(data, type='global')
plt.imshow(vis_filters(data))

filters2 = net.params['conv2'][0].data
(num_filters2, num_channels2, _, _) = filters2.shape

filters3 = net.params['conv3'][0].data
(num_filters3, num_channels3, _, _) = filters3.shape

print filenames
#filenames = filenames[1:]
# Out:
# ../examples/cfw/cfw_deploy_v5.prototxt
# ../examples/cfw/4layers_v5/cfw_iter_1000
# ['cfw_iter_500', 'cfw_iter_1000', 'cfw_iter_1500', 'cfw_iter_2000', 'cfw_iter_2500', 'cfw_iter_3000', 'cfw_iter_3500', 'cfw_iter_4000', 'cfw_iter_4500', 'cfw_iter_5000', 'cfw_iter_5500', 'cfw_iter_6000', 'cfw_iter_6500', 'cfw_iter_7000', 'cfw_iter_7500', 'cfw_iter_8000', 'cfw_iter_8500', 'cfw_iter_9000', 'cfw_iter_9500', 'cfw_iter_10000', 'cfw_iter_10500', 'cfw_iter_11000', 'cfw_iter_11500', 'cfw_iter_12000', 'cfw_iter_12500', 'cfw_iter_13000', 'cfw_iter_13500', 'cfw
cfw_iter_81500', 'cfw_iter_82000', 'cfw_iter_82500', 'cfw_iter_83000', 'cfw_iter_83500', 'cfw_iter_84000', 'cfw_iter_84500', 'cfw_iter_85000', 'cfw_iter_85500', 'cfw_iter_86000', 'cfw_iter_86500', 'cfw_iter_87000', 'cfw_iter_87500', 'cfw_iter_88000', 'cfw_iter_88500', 'cfw_iter_89000', 'cfw_iter_89500', 'cfw_iter_90000', 'cfw_iter_90500', 'cfw_iter_91000', 'cfw_iter_91500', 'cfw_iter_92000', 'cfw_iter_92500', 'cfw_iter_93000', 'cfw_iter_93500', 'cfw_iter_94000', 'cfw_iter_94500', 'cfw_iter_95000', 'cfw_iter_95500', 'cfw_iter_96000', 'cfw_iter_96500', 'cfw_iter_97000', 'cfw_iter_97500', 'cfw_iter_98000', 'cfw_iter_98500', 'cfw_iter_99000', 'cfw_iter_99500', 'cfw_iter_100000', 'cfw_iter_100500', 'cfw_iter_101000', 'cfw_iter_101500', 'cfw_iter_102000', 'cfw_iter_102500', 'cfw_iter_103000', 'cfw_iter_103500', 'cfw_iter_104000', 'cfw_iter_104500', 'cfw_iter_105000', 'cfw_iter_105500', 'cfw_iter_106000', 'cfw_iter_106500', 'cfw_iter_107000', 'cfw_iter_107500', 'cfw_iter_108000', 'cfw_iter_108500', 'cfw_iter_109000', 'cfw_iter_109500', 'cfw_iter_110000', 'cfw_iter_110500', 'cfw_iter_111000',  ...

# %%
print filenames[1:][::20]
print len(filenames[1:][::20])
# Out:
# ['cfw_iter_1000', 'cfw_iter_11000', 'cfw_iter_21000', 'cfw_iter_31000', 'cfw_iter_41000', 'cfw_iter_51000', 'cfw_iter_61000', 'cfw_iter_71000', 'cfw_iter_81000', 'cfw_iter_91000', 'cfw_iter_101000', 'cfw_iter_111000', 'cfw_iter_121000', 'cfw_iter_131000', 'cfw_iter_141000', 'cfw_iter_151000', 'cfw_iter_161000', 'cfw_iter_171000', 'cfw_iter_181000', 'cfw_iter_191000', 'cfw_iter_201000', 'cfw_iter_211000', 'cfw_iter_221000', 'cfw_iter_231000', 'cfw_iter_241000', 'cfw_iter_251000', 'cfw_iter_261000', 'cfw_iter_271000', 'cfw_iter_281000', 'cfw_iter_291000', 'cfw_iter_301000', 'cfw_iter_311000', 'cfw_iter_321000', 'cfw_iter_331000', 'cfw_iter_341000', 'cfw_iter_351000', 'cfw_iter_361000', 'cfw_iter_371000', 'cfw_iter_381000', 'cfw_iter_391000', 'cfw_iter_401000', 'cfw_iter_411000', 'cfw_iter_421000', 'cfw_iter_431000', 'cfw_iter_441000', 'cfw_iter_451000']
# 46

# %%
#filters3 = net.params['ip1'][0].data

all_filters = []
all_filters2 = []
all_filters3 = []


print filenames[1:][::50]

for f in filenames[1:][::50]:
    print net_root + subdirectory + f
    net = caffe.Classifier(net_root + DEPLOY_FILE, net_root + subdirectory + f)
    filters = net.params['conv1'][0].data
    filters2 = net.params['conv2'][0].data
    filters3 = net.params['conv3'][0].data
    #filters3 = net.params['ip1'][0].data
    #filters3 = filters3.squeeze()[:1024] # display first 1024 dim
    #filters3 *= 1.0/filters3.max()
    
    print filters.shape
    
    filters = filters.transpose(0, 2, 3, 1)
    filters = norm_filters(filters, type='cellwise')
    data = vis_filters(filters)
    data = norm_filters(data, type='global')


    all_filters.append(data)
    
    filters2 = net.params['conv2'][0].data
    filters2 = norm_filters(filters2, type='inputwise')
    filters2 = filters2.reshape(num_filters2*num_channels2, 5, 5)
    data = vis_filters_rect(filters2, n=num_filters2)
    data = norm_filters(data, type='global')
    
    all_filters2.append(data)
    
    filters3 = net.params['conv3'][0].data
    filters3 = norm_filters(filters3, type='inputwise')
    filters3 = filters3.reshape(num_filters3*num_channels3, 5, 5)
    data = vis_filters_rect(filters3, n=num_filters3)
    data = norm_filters(data, type='global')

    all_filters3.append(data)

    
    #all_filters3.append(filters3)

images2gif.writeGif('one.gif', all_filters, duration=0.8)
images2gif.writeGif('two.gif', all_filters2, duration=0.8)
images2gif.writeGif('three.gif', all_filters3, duration=0.8)
#images2gif.writeGif('ip.gif', all_filters3, duration=1)
# Out:
# ['cfw_iter_1000', 'cfw_iter_26000', 'cfw_iter_51000', 'cfw_iter_76000', 'cfw_iter_101000', 'cfw_iter_126000', 'cfw_iter_151000', 'cfw_iter_176000', 'cfw_iter_201000', 'cfw_iter_226000', 'cfw_iter_251000', 'cfw_iter_276000', 'cfw_iter_301000', 'cfw_iter_326000', 'cfw_iter_351000', 'cfw_iter_376000', 'cfw_iter_401000', 'cfw_iter_426000', 'cfw_iter_451000']
# ../examples/cfw/4layers_v5/cfw_iter_1000
# (20, 3, 11, 11)
# ../examples/cfw/4layers_v5/cfw_iter_26000
# (20, 3, 11, 11)
# ../examples/cfw/4layers_v5/cfw_iter_51000
# (20, 3, 11, 11)
# ../examples/cfw/4layers_v5/cfw_iter_76000
# (20, 3, 11, 11)
# ../examples/cfw/4layers_v5/cfw_iter_101000
# (20, 3, 11, 11)
# ../examples/cfw/4layers_v5/cfw_iter_126000
# (20, 3, 11, 11)
# ../examples/cfw/4layers_v5/cfw_iter_151000
# (20, 3, 11, 11)
# ../examples/cfw/4layers_v5/cfw_iter_176000
# (20, 3, 11, 11)
# ../examples/cfw/4layers_v5/cfw_iter_201000
# (20, 3, 11, 11)
# ../examples/cfw/4layers_v5/cfw_iter_226000
# (20, 3, 11, 11)
# ../examples/cfw/4layers_v5/cfw_iter_251000
# (20, 3, 11, 11)
# ../examples/cfw/4layers_v5/cfw_iter_276000
# (20, 3, 11, 11)
# ../examples/cfw/4layers_v5/cfw_iter_301000
# (20, 3, 11, 11)
# ../examples/cfw/4layers_v5/cfw_iter_326000
# (20, 3, 11, 11)
# ../examples/cfw/4layers_v5/cfw_iter_351000
# (20, 3, 11, 11)
# ../examples/cfw/4layers_v5/cfw_iter_376000
# (20, 3, 11, 11)
# ../examples/cfw/4layers_v5/cfw_iter_401000
# (20, 3, 11, 11)
# ../examples/cfw/4layers_v5/cfw_iter_426000
# (20, 3, 11, 11)
# ../examples/cfw/4layers_v5/cfw_iter_451000
# (20, 3, 11, 11)

# %%
net = caffe.Classifier(net_root + DEPLOY_FILE, net_root + subdirectory + filenames[-1])

#filters = net.params['conv1'][0].data
#data = vis_square(filters.transpose(0, 2, 3, 1))

def vis_filters(data, padsize=1, padval=0):    
    # force the number of filters to be square
    n = int(np.ceil(np.sqrt(data.shape[0])))
    padding = ((0, n ** 2 - data.shape[0]), (0, padsize), (0, padsize)) + ((0, 0),) * (data.ndim - 3)
    data = np.pad(data, padding, mode='constant', constant_values=(padval, padval))
    
    # tile the filters into an image
    data = data.reshape((n, n) + data.shape[1:]).transpose((0, 2, 1, 3) + tuple(range(4, data.ndim + 1)))
    data = data.reshape((n * data.shape[1], n * data.shape[3]) + data.shape[4:])
    return data

def vis_filters_rect(data, n, padsize=1, padval=0):    
    # force the number of filters to be square
    m = data.shape[0] / n
    padding = ((0, n * m - data.shape[0]), (0, padsize), (0, padsize)) + ((0, 0),) * (data.ndim - 3)
    data = np.pad(data, padding, mode='constant', constant_values=(padval, padval))
    
    # tile the filters into an image
    data = data.reshape((n, m) + data.shape[1:]).transpose((0, 2, 1, 3) + tuple(range(4, data.ndim + 1)))
    data = data.reshape((n * data.shape[1], m * data.shape[3]) + data.shape[4:])
    return data


def norm_filters(data, type='global'):
    if type == 'global':
        data -= data.min()
        data /= data.max()
    elif type == 'cellwise':
        for i in range(data.shape[0]):
            data[i, :, :, :] -= data[i].min()
            data[i, :, :, :] /= data[i].max()
    elif type == 'inputwise':
        for i in range(data.shape[1]):
            data[:, i, :, :] /= abs(data[:, i, :, :]).max()

    else:
        print "norm type unknown"
    return data


filters3 = net.params['conv3'][0].data
filters3 = norm_filters(filters3, type='inputwise')

print filters3.shape

print num_filters3
print num_channels3

filters3 = filters3.reshape(num_filters3*num_channels3, 5, 5)

data = vis_filters_rect(filters3, n=num_filters3)

plt.imshow(data)
plt.set_cmap('gray')

print data.shape
print filters2.shape
# Out:
# (60, 40, 5, 5)
# 60
# 40
# (360, 240)
# (40, 20, 5, 5)

# %%
from caffe.proto import caffe_pb2
blob = caffe_pb2.BlobProto()
mean_file = open(data_root + MEAN_FILE, "rb").read()
#mean_file = open(caffe_root + 'data/lfw/mean250.binaryproto')
blob.ParseFromString(mean_file)
#print blob
mean = np.array(caffe.io.blobproto_to_array(blob))
print mean.shape
mean = mean[0]
print "Mean shape: " + str(mean.shape)
np.save(data_root + 'mean.npy', mean)
# Out:
# (1, 3, 250, 200)
# Mean shape: (3, 250, 200)

# %%
filenames = os.listdir(net_root + subdirectory)
filenames = filter(lambda f: not re.search(r'\d+$', f) == None, filenames)
sort_nicely(filenames)
f = filenames[-1]

net = caffe.Classifier(net_root + DEPLOY_FILE, net_root + subdirectory + f, channel_swap=(2, 1, 0),
                       mean_file=data_root + 'mean.npy', input_scale=0.00390625)

net.set_phase_train()
net.set_mode_cpu()

print "Loading net: " + net_root + DEPLOY_FILE
print "Snapshot: " + subdirectory + f
# Out:
# Loading net: ../examples/cfw/cfw_deploy_v5.prototxt
# Snapshot: 4layers_v5/cfw_iter_457000

# %% [markdown]
# ### Load Images and Labels

# %%
from numpy import random

NUM_IMAGES = 128
NUM_IMAGES = 1427 # NUM_IMAGES in test set

side = int(np.sqrt(NUM_IMAGES))


with open(data_root + TEST_FILE) as test_file:
    head = [tuple(i.split()) for i in random.choice(list(test_file), NUM_IMAGES)] # random
    #head = [tuple(next(test_file).split()) for i in range(NUM_IMAGES)] # sequential
    names, labels = zip(*head)
    
input_images = [caffe.io.load_image(data_root + n) for n in names]

with open(data_root + LABELS_FILE) as labels_file:
    rows = [line.split(' ') for line in labels_file]
    celeb_names = {row[1][:-1]:row[0] for row in rows}

# %% [markdown]
# ### Plot test sample

# %%
# FOR TEST: CHECK HOW PREDICTION ZERO PADS
prediction = net.predict(input_images, oversample=False)
top = np.argmax(prediction, axis=1)

acc = 0
for l, t in zip(labels, top):
    if int(l) == int(t):
        acc += 1
print "Accuracy: " + str(acc/float(len(labels)))
# Out:
# Accuracy: 0.4921875

# %%
side = 6
fig, ax = plt.subplots(side, side)
fig.tight_layout()

for i in range(side):
    for j in range(side):
        im = plt.imread(data_root + names[i*side + j])
        ax[i][j].imshow(im)
        ax[i][j].set_xticklabels([])
        ax[i][j].set_yticklabels([])
        ax[i][j].set_title(celeb_names[labels[i*side + j]] + '\n' + 
                           celeb_names[str(top[i*side + j])], fontsize=10)

# %%
#print net.blobs.keys()
#print net.blobs.values()

#print net.blobs['ip1'].data.shape
print top

# %%
for i, t in enumerate(top): 
    if int(t) == int(labels[i]):
        print str(i) + '\t' + str(t) + '\t' + str(labels[i]) 

print enumerate(labels)
#print prediction[0].argsort()[-4:][::-1]
# Out:
# 0	0	0
# 1	1	1
# 5	5	5
# 6	5	5
# 7	6	6
# 9	12	12
# 11	15	15
# 12	15	15
# 14	15	15
# 15	16	16
# 16	17	17
# 21	18	18
# 22	18	18
# 23	18	18
# 25	21	21
# 26	22	22
# 28	22	22
# 33	28	28
# 35	28	28
# 37	28	28
# 39	28	28
# 41	28	28
# 42	28	28
# 43	28	28
# 44	28	28
# 45	28	28
# 47	28	28
# 49	28	28
# 50	28	28
# 52	28	28
# 53	29	29
# 56	29	29
# 57	34	34
# 58	41	41
# 59	41	41
# 60	42	42
# 62	46	46
# 67	51	51
# 69	58	58
# 70	64	64
# 72	69	69
# 73	71	71
# 74	75	75
# 75	75	75
# 76	76	76
# 77	77	77
# 80	81	81
# 82	83	83
# 84	92	92
# 85	94	94
# 86	94	94
# 87	100	100
# 88	101	101
# 89	101	101
# 90	103	103
# 92	105	105
# 93	107	107
# 94	107	107
# 97	112	112
# 98	112	112
# 101	113	113
# 102	113	113
# 104	114	114
# 105	114	114
# 106	114	114
# 108	114	114
# 109	114	114
# 110	114	114
# 111	114	114
# 112	114	114
# 113	114	114
# 114	114	114
# 115	114	114
# 116	114	114
# 117	114	114
# 125	123	123
# 126	123	123
# 128	123	123
# 129	123	123
# 132	123	123
# 138	130	130
# 142	137	137
# 144	140	140
# 146	147	147
# 147	149	149
# 151	154	154
# 154	158	158
# 161	171	171
# 162	171	171
# 163	171	171
# 165	171	171
# 166	171	171
# 167	171	171
# 168	171	171
# 176	174	174
# 179	176	176
# 181	177	177
# 182	177	177
# 184	177	177
# 186	181	181
# 187	181	181
# 188	181	181
# 189	184	184
# 190	184	184
# 192	184	184
# 195	184	184
# 196	184	184
# 197	184	184
# 198	184	184
# 202	191	191
# 203	191	191
# 205	194	194
# 212	207	207
# 214	212	212
# 215	213	213
# 219	216	216
# 226	229	229
# 227	229	229
# 228	235	235
# 229	235	235
# 230	235	235
# 231	236	236
# 232	236	236
# 233	236	236
# 234	236	236
# 235	236	236
# 238	243	243
# 240	243	243
# 241	244	244
# 242	246	246
# 245	256	256
# 247	261	261
# 249	262	262
# 252	269	269
# 254	276	276
# 256	277	277
# 259	296	296
# 260	297	297
# 261	299	299
# 262	301	301
# 263	301	301
# 265	303	303
# 266	304	304
# 269	308	308
# 274	324	324
# 277	324	324
# 278	324	324
# 279	325	325
# 280	328	328
# 281	328	328
# 282	331	331
# 285	336	336
# 286	336	336
# 287	336	336
# 289	336	336
# 290	340	340
# 292	341	341
# 293	346	346
# 297	361	361
# 299	368	368
# 300	369	369
# 304	372	372
# 305	373	373
# 306	373	373
# 307	377	377
# 309	380	380
# 310	380	380
# 311	381	381
# 312	381	381
# 314	383	383
# 315	385	385
# 316	387	387
# 317	387	387
# 319	387	387
# 320	387	387
# 326	396	396
# 328	396	396
# 329	396	396
# 330	396	396
# 333	399	399
# 334	399	399
# 336	401	401
# 337	401	401
# 338	401	401
# 339	401	401
# 342	403	403
# 345	410	410
# 346	410	410
# 348	410	410
# 350	412	412
# 356	424	424
# 357	426	426
# 358	426	426
# 359	427	427
# 362	435	435
# 363	436	436
# 364	438	438
# 365	438	438
# 366	445	445
# 368	448	448
# 369	450	450
# 370	450	450
# 371	450	450
# 372	452	452
# 375	457	457
# 378	459	459
# 385	467	467
# 390	472	472
# 392	473	473
# 393	473	473
# 394	473	473
# 396	479	479
# 397	480	480
# 399	483	483
# 408	492	492
# 410	493	493
# 413	495	495
# 414	498	498
# 416	499	499
# 417	499	499
# 418	499	499
# 419	499	499
# 422	507	507
# 425	508	508
# 426	508	508
# 428	512	512
# 430	515	515
# 436	523	523
# 438	528	528
# 441	528	528
# 444	528	528
# 447	528	528
# 448	528	528
# 449	528	528
# 450	528	528
# 451	528	528
# 452	528	528
# 453	528	528
# 454	528	528
# 456	528	528
# 457	528	528
# 458	528	528
# 459	528	528
# 461	530	530
# 463	530	530
# 466	532	532
# 469	533	533
# 470	533	533
# 471	535	535
# 475	540	540
# 479	552	552
# 480	552	552
# 482	552	552
# 489	556	556
# 490	556	556
# 491	556	556
# 494	566	566
# 495	566	566
# 497	568	568
# 498	568	568
# 499	569	569
# 500	569	569
# 501	570	570
# 502	570	570
# 505	572	572
# 506	575	575
# 508	577	577
# 509	577	577
# 510	579	579
# 511	581	581
# 512	581	581
# 513	581	581
# 515	584	584
# 516	584	584
# 517	584	584
# 519	588	588
# 520	589	589
# 521	589	589
# 522	589	589
# 525	592	592
# 526	592	592
# 527	592	592
# 528	592	592
# 533	592	592
# 534	592	592
# 535	592	592
# 536	592	592
# 538	592	592
# 543	598	598
# 544	599	599
# 545	599	599
# 547	603	603
# 549	603	603
# 550	603	603
# 551	603	603
# 555	608	608
# 556	608	608
# 557	608	608
# 558	608	608
# 561	610	610
# 562	610	610
# 563	610	610
# 565	610	610
# 570	620	620
# 571	620	620
# 573	625	625
# 574	627	627
# 575	627	627
# 577	630	630
# 579	631	631
# 581	632	632
# 585	635	635
# 586	635	635
# 587	635	635
# 588	635	635
# 591	637	637
# 592	637	637
# 593	637	637
# 594	637	637
# 595	637	637
# 596	637	637
# 597	638	638
# 598	639	639
# 599	639	639
# 600	639	639
# 601	639	639
# 610	649	649
# 611	650	650
# 615	656	656
# 616	659	659
# 617	659	659
# 618	659	659
# 620	659	659
# 622	659	659
# 625	659	659
# 627	662	662
# 628	664	664
# 629	664	664
# 630	664	664
# 632	665	665
# 634	670	670
# 635	670	670
# 639	670	670
# 640	670	670
# 641	670	670
# 642	674	674
# 643	674	674
# 645	674	674
# 646	679	679
# 648	687	687
# 649	688	688
# 650	689	689
# 651	689	689
# 653	694	694
# 654	694	694
# 656	696	696
# 659	705	705
# 660	705	705
# 661	705	705
# 665	715	715
# 667	716	716
# 673	720	720
# 675	721	721
# 676	722	722
# 677	722	722
# 679	728	728
# 680	728	728
# 681	728	728
# 682	728	728
# 688	735	735
# 689	735	735
# 692	738	738
# 694	738	738
# 696	738	738
# 697	738	738
# 698	740	740
# 700	740	740
# 702	740	740
# 703	740	740
# 704	741	741
# 705	741	741
# 706	751	751
# 707	751	751
# 715	760	760
# 716	760	760
# 717	761	761
# 719	761	761
# 723	775	775
# 724	779	779
# 727	782	782
# 728	784	784
# 729	784	784
# 731	789	789
# 732	790	790
# 735	791	791
# 737	794	794
# 738	796	796
# 739	797	797
# 741	797	797
# 742	797	797
# 743	797	797
# 744	797	797
# 747	803	803
# 748	803	803
# 756	822	822
# 764	843	843
# 768	846	846
# 769	846	846
# 770	853	853
# 772	853	853
# 775	859	859
# 777	861	861
# 779	862	862
# 780	862	862
# 782	865	865
# 783	865	865
# 786	873	873
# 787	873	873
# 788	874	874
# 790	875	875
# 793	882	882
# 794	883	883
# 798	883	883
# 799	883	883
# 800	884	884
# 801	886	886
# 803	889	889
# 809	903	903
# 810	903	903
# 812	903	903
# 816	913	913
# 817	915	915
# 819	917	917
# 821	917	917
# 822	920	920
# 827	928	928
# 828	928	928
# 829	928	928
# 830	929	929
# 832	929	929
# 833	929	929
# 835	929	929
# 838	933	933
# 842	938	938
# 843	938	938
# 844	939	939
# 851	954	954
# 852	954	954
# 853	955	955
# 854	957	957
# 859	964	964
# 860	964	964
# 863	970	970
# 870	980	980
# 871	980	980
# 872	981	981
# 874	985	985
# 875	985	985
# 878	985	985
# 880	987	987
# 1181	1323	1323
# 1184	1326	1326
# 1185	1332	1332
# 1186	1332	1332
# 1188	1333	1333
# 1189	1336	1336
# 1190	1337	1337
# 1191	1338	1338
# 1197	1343	1343
# 1198	1343	1343
# 1199	1343	1343
# 1201	1348	1348
# 1203	1352	1352
# 1204	1352	1352
# 1206	1358	1358
# 1207	1358	1358
# 1208	1361	1361
# 1212	1366	1366
# 1214	1369	1369
# 1215	1372	1372
# 1216	1372	1372
# 1218	1375	1375
# 1219	1375	1375
# 1220	1375	1375
# 1222	1376	1376
# 1226	1387	1387
# 1229	1396	1396
# 1230	1397	1397
# 1231	1400	1400
# 1232	1401	1401
# 1233	1401	1401
# 1234	1401	1401
# 1236	1401	1401
# 1237	1401	1401
# 1238	1401	1401
# 1239	1401	1401
# 1242	1405	1405
# 1246	1411	1411
# 1250	1419	1419
# 1252	1424	1424
# 1255	1426	1426
# 1258	1433	1433
# 1261	1440	1440
# 1265	1447	1447
# 1266	1452	1452
# 1269	1456	1456
# 1270	1457	1457
# 1271	1458	1458
# 1273	1458	1458
# 1274	1459	1459
# 1276	1464	1464
# 1277	1466	1466
# 1278	1467	1467
# 1279	1467	1467
# 1282	1471	1471
# 1286	1476	1476
# 1287	1484	1484
# 1289	1492	1492
# 1290	1494	1494
# 1291	1495	1495
# 1292	1501	1501
# 1295	1504	1504
# 1296	1504	1504
# 1298	1504	1504
# 1299	1504	1504
# 1301	1506	1506
# 1302	1508	1508
# 1303	1508	1508
# 1305	1508	1508
# 1307	1508	1508
# 1308	1508	1508
# 1309	1508	1508
# 1313	1511	1511
# 1317	1518	1518
# 1318	1518	1518
# 1319	1518	1518
# 1322	1522	1522
# 1324	1524	1524
# 1326	1528	1528
# 1328	1529	1529
# 1333	1537	1537
# 1334	1539	1539
# 1339	1543	1543
# 1342	1548	1548
# 1346	1556	1556
# 1348	1559	1559
# 1349	1559	1559
# 1350	1559	1559
# 1351	1559	1559
# 1354	1559	1559
# 1355	1559	1559
# 1356	1559	1559
# 1357	1559	1559
# 1358	1559	1559
# 1359	1559	1559
# 1361	1561	1561
# 1363	1563	1563
# 1364	1563	1563
# 1366	1566	1566
# 1369	1568	1568
# 1372	1573	1573
# 1374	1573	1573
# 1375	1573	1573
# 1376	1573	1573
# 1377	1573	1573
# 1380	1580	1580
# <enumerate object at 0x3eff0a00>

# %%
with open(data_root + TEST_FILE) as test_file:
    head = [i.split() for i in random.choice(list(test_file), 10)]
    print head
# Out:
# [['cfw_full_vj_small/kim_kardashian/70_0.jpg', '1034'], ['cfw_full_vj_small/paul_rudd/29_0.jpg', '1082'], ['cfw_full_vj_small/cameron_diaz/313_0.jpg', '738'], ['cfw_full_vj_small/ian_somerhalder/0_0.jpg', '148'], ['cfw_full_vj_small/jennifer_lopez/1187_0.jpg', '589'], ['cfw_full_vj_small/josh_hartnett/108_0.jpg', '1349'], ['cfw_full_vj_small/amy_acker/43_0.jpg', '273'], ['cfw_full_vj_small/jessica_biel/429_0.jpg', '229'], ['cfw_full_vj_small/barack_obama/369_0.jpg', '528'], ['cfw_full_vj_small/britney_spears/2187_0.jpg', '28']]

# %%
random.choice?

# %%
import skimage
skimage.img_as_float?

# %%
\
